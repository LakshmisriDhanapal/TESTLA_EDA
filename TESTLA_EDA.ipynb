# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmisriDhanapal/TESTLA_EDA/blob/main/TESTLA_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
f=pd.read_csv("/content/drive/MyDrive/TSLA.csv")

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3383 entries, 0 to 3382
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3383 non-null   object
#  1   Open       3383 non-null   float64
#  2   High       3383 non-null   float64
#  3   Low        3383 non-null   float64
#  4   Close      3383 non-null   float64
#  5   Adj Close  3383 non-null   float64
#  6   Volume     3383 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 185.1+ KB

# %%
f.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1  2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2  2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3  2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4  2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
f.tail
# Out:
# <bound method NDFrame.tail of             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3378  2023-11-29  249.210007  252.750000  242.759995  244.139999  244.139999
# 3379  2023-11-30  245.139999  245.220001  236.910004  240.080002  240.080002
# 3380  2023-12-01  233.139999  240.190002  231.899994  238.830002  238.830002
# 3381  2023-12-04  235.750000  239.369995  233.289993  235.580002  235.580002
# 3382  2023-12-05  233.869995  246.660004  233.699997  238.720001  238.720001
#
# ...

# %%
f.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
f.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3383.000000  3383.000000  3383.000000  3383.000000  3383.000000
# mean     69.595920    71.139907    67.934383    69.578123    69.578123
# std     101.016818   103.287828    98.520375   100.941653   100.941653
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%      10.422334    10.824666    10.210000    10.544000    10.544000
# 50%      16.866667    17.132668    16.625999    16.879333    16.879333
# 75%      99.818333   102.410663    97.599998    99.872333    99.872333
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.383000e+03
# mean   9.672717e+07
# std    8.022900e+07
# min    1.777500e+06
# 25%    4.574925e+07
# 50%    8.098950e+07
# 75%    1.234176e+08
# max    9.140820e+08

# %%
f.describe(include=['int'])
# Out:
#              Volume
# count  3.383000e+03
# mean   9.672717e+07
# std    8.022900e+07
# min    1.777500e+06
# 25%    4.574925e+07
# 50%    8.098950e+07
# 75%    1.234176e+08
# max    9.140820e+08

# %%
f.describe(include=['int','float'])
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3383.000000  3383.000000  3383.000000  3383.000000  3383.000000
# mean     69.595920    71.139907    67.934383    69.578123    69.578123
# std     101.016818   103.287828    98.520375   100.941653   100.941653
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%      10.422334    10.824666    10.210000    10.544000    10.544000
# 50%      16.866667    17.132668    16.625999    16.879333    16.879333
# 75%      99.818333   102.410663    97.599998    99.872333    99.872333
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.383000e+03
# mean   9.672717e+07
# std    8.022900e+07
# min    1.777500e+06
# 25%    4.574925e+07
# 50%    8.098950e+07
# 75%    1.234176e+08
# max    9.140820e+08

# %%
f.groupby(['Volume']).agg({'High_energy_generate':'mean'})
# Out:
#            High_energy_generate
# Volume
# 1777500                1.398667
# 2115000                1.376000
# 2416500                1.395333
# 2442000                1.376000
# 2568000                1.380000
# ...                         ...
# 598212000             53.055332
# 666378600            231.666672
# 705975000             52.409332
# 726357000             56.398666
# 914082000             64.599335
#
# [3352 rows x 1 columns]

# %%
f.filter(items=['High_energy_generate','Low_energy_generate'])
# Out:
#       High_energy_generate  Low_energy_generate
# 0                 1.666667             1.169333
# 1                 2.028000             1.553333
# 2                 1.728000             1.351333
# 3                 1.540000             1.247333
# 4                 1.333333             1.055333
# ...                    ...                  ...
# 3378            252.750000           242.759995
# 3379            245.220001           236.910004
# 3380            240.190002           231.899994
# 3381            239.369995           233.289993
# 3382            246.660004           233.699997
#
# [3383 rows x 2 columns]

# %%
f.rename(columns={"High":"High_energy_generate","Low":"Low_energy_generate"},inplace=True)
f.head()
# Out:
#          Date      Open  High_energy_generate  Low_energy_generate     Close  \
# 0  2010-06-29  1.266667              1.666667             1.169333  1.592667
# 1  2010-06-30  1.719333              2.028000             1.553333  1.588667
# 2  2010-07-01  1.666667              1.728000             1.351333  1.464000
# 3  2010-07-02  1.533333              1.540000             1.247333  1.280000
# 4  2010-07-06  1.333333              1.333333             1.055333  1.074000
#
#    Adj Close     Volume
# 0   1.592667  281494500
# 1   1.588667  257806500
# 2   1.464000  123282000
# 3   1.280000   77097000
# 4   1.074000  103003500

# %%
f.iloc[:,[1,4]]
# Out:
#             Open       Close
# 0       1.266667    1.592667
# 1       1.719333    1.588667
# 2       1.666667    1.464000
# 3       1.533333    1.280000
# 4       1.333333    1.074000
# ...          ...         ...
# 3378  249.210007  244.139999
# 3379  245.139999  240.080002
# 3380  233.139999  238.830002
# 3381  235.750000  235.580002
# 3382  233.869995  238.720001
#
# [3383 rows x 2 columns]

# %%
f.loc[:,"Volume"]
# Out:
# 0       281494500
# 1       257806500
# 2       123282000
# 3        77097000
# 4       103003500
#           ...
# 3378    135401300
# 3379    132353200
# 3380    121173500
# 3381    104099800
# 3382    137690100
# Name: Volume, Length: 3383, dtype: int64

# %%
yearly_analysis.plot(x='year',y='Close')
plt.title('Tesla stock price')
plt.figure(figsize=(10,5))
plt.show()

# %%
f["Date"]=pd.to_datetime(f["Date"])
f['year']=f["Date"].dt.year
f["year"]
# Out:
# 0       2010
# 1       2010
# 2       2010
# 3       2010
# 4       2010
#         ...
# 3378    2023
# 3379    2023
# 3380    2023
# 3381    2023
# 3382    2023
# Name: year, Length: 3383, dtype: int64

# %%
f
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3378 2023-11-29  249.210007  252.750000  242.759995  244.139999  244.139999
# 3379 2023-11-30  245.139999  245.220001  236.910004  240.080002  240.080002
# 3380 2023-12-01  233.139999  240.190002  231.899994  238.830002  238.830002
# 3381 2023-12-04  235.750000  239.369995  233.289993  235.580002  235.580002
# 3382 2023-12-05  233.869995  246.660004  233.699997  238.720001  238.720001
#
#          Volume  year
# 0     281494500  2010
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
yearly_analysis.plot(x='year',y='Open',kind='bar',color="green",)
plt.title('Tesla stock price')
plt.xlabel('year')
plt.ylabel('Volume')
plt.show()

# %%
import seaborn as sns

sns.boxplot(f.Close)
plt.title('Close')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data=f, x='Open', kde=True)
plt.title('Tesla stock for open')
# Out:
# Text(0.5, 1.0, 'Tesla stock for open')

# %%
sns.histplot(data=f, x='Close', kde=True)
plt.title('Tesla stock for Close')
# Out:
# Text(0.5, 1.0, 'Tesla stock for Close')

# %%
sns.histplot(data=f, x='Adj Close', kde=True)
plt.title('Tesla stock for Adj Close')
# Out:
# Text(0.5, 1.0, 'Tesla stock for Adj Close')

# %%
sns.histplot(data=f, x='High', kde=True)
plt.title('Tesla stock for High')
# Out:
# Text(0.5, 1.0, 'Tesla stock for High')

# %%
sns.histplot(data=f, x='Low', kde=True)
plt.title('Tesla stock for Low')
# Out:
# Text(0.5, 1.0, 'Tesla stock for Low')

# %%
sns.pairplot(data=f[f.select_dtypes(include=[int,float]).columns])
plt.title("Linear Relationship between the Volume")
plt.show()
